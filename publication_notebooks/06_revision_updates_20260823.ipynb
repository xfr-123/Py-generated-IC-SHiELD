# %% [markdown]
# # Publication Revision Update — August 23, 2026
#
# This notebook consolidates the figure and table updates produced during the current revision round. The six earlier publication notebooks are retained as a historical reproducibility record; this notebook identifies the revised artifacts that supersede their corresponding presentation or diagnostic definitions.
#
# Key terminology is standardized to **constant $u_0$** and **constant $U_{\max}=30$ m s$^{-1}$**. Cyclone and anticyclone feature diagnostics use the eddy surface-pressure field where specified. No manuscript or Word document is generated or edited by this notebook.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import Image, display

ROOT = Path.cwd()
if not (ROOT / 'publication_notebooks').exists():
    ROOT = ROOT.parent
ASSET_ROOT = ROOT / 'publication_notebooks' / 'revision_20260823'
manifest = pd.read_csv(ASSET_ROOT / 'revision_manifest.csv')
manifest[['label', 'title', 'scientific_or_presentation_change']]
# Out:
#                                   label  \
# 0                      Current Figure 6
# 1                EKE evolution revision
# 2                      Current Figure 9
# 3                     Current Figure 10
# 4                     Current Figure 11
# 5                     Current Figure 12
# 6         Heatmap presentation revision
# 7                     SI Figures S9–S10
# 8                         SI Figure S11
# 9                    SI Figures S12–S13
# 10                        SI Figure S14
# 11                        SI Figure S15
# 12                        SI Figure S19
# 13                   SI Figures S20–S21
# 14                             Table S3
# 15     EP-flux supplementary diagnostic
# 16  Initial-PV supplementary diagnostic
# 17  Section 3.2 consolidated diagnostic
#
#                                                 title  \
# 0         RWB statistics for the constant-u0 ensemble
# 1   NH EKE evolution with initial 30–70°N Eady-gro...
# ...

# %% [markdown]
# ## Current Figure 6: RWB statistics for the constant-u0 ensemble
#
# Uses only the 45 constant-u0 simulations and removes the in-figure overall title.
#
# - Script: `revision_20260823/artifacts/main_rwb_constant_u0/scripts/replot_figure5_rwb_constant_u0_no_suptitle.py`
#
# ![RWB statistics for the constant-u0 ensemble](revision_20260823/artifacts/main_rwb_constant_u0/figures/Figure6_RWB_fraction_constant_u0_no_suptitle.png)

# %% [markdown]
# ## EKE evolution revision: NH EKE evolution with initial 30–70°N Eady-growth context
#
# Adds experiment legends and initial midlatitude Eady-growth annotations using the NH-consistent diagnostic.
#
# - Script: `revision_20260823/artifacts/main_eke_midlatitude_eady/scripts/plot_figure6_eke_with_midlatitude_eady.py`
# - Supporting data: `revision_20260823/artifacts/main_eke_midlatitude_eady/tables/Figure6_initial_midlatitude_Eady_annotations.csv`
#
# ![NH EKE evolution with initial 30–70°N Eady-growth context](revision_20260823/artifacts/main_eke_midlatitude_eady/figures/Figure6_EKE_evolution_with_midlatitude_Eady_mean.png)

# %%
table_path = ROOT / 'publication_notebooks' / 'revision_20260823/artifacts/main_eke_midlatitude_eady/tables/Figure6_initial_midlatitude_Eady_annotations.csv'
pd.read_csv(table_path).head(10)
# Out:
#                case    b  n   s  initial_eady_area_mass_weighted_30_70N_day-1  \
# 0   BCwave_b1n1s-10  1.0  1 -10                                      0.278054
# 1       BCwave_b1n1  1.0  1   0                                      0.336661
# 2    BCwave_b1n1s10  1.0  1  10                                      0.331256
# 3   BCwave_b1n3s-10  1.0  3 -10                                      0.200406
# 4       BCwave_b1n3  1.0  3   0                                      0.268753
# 5    BCwave_b1n3s10  1.0  3  10                                      0.256039
# 6   BCwave_b1n6s-10  1.0  6 -10                                      0.158551
# 7       BCwave_b1n6  1.0  6   0                                      0.213400
# 8    BCwave_b1n6s10  1.0  6  10                                      0.199719
# 9  BCwave_b15n1s-10  1.5  1 -10                                      0.345850
#
#    eady_valid_weight_fraction  eady_domain_latitude_min_deg  \
# ...

# %% [markdown]
# ## Current Figure 9: Cyclone interaction from eddy surface pressure
#
# Combines the hemispheric evolution and the b2n3s10 local zoom using eddy-SLP contours.
#
# - Script: `revision_20260823/artifacts/main_cyclone_overview/scripts/reorganize_eddy_cyclone_figures.py`
#
# ![Cyclone interaction from eddy surface pressure](revision_20260823/artifacts/main_cyclone_overview/figures/Figure9_eddy_cyclone_overview_plus_zoom.png)

# %% [markdown]
# ## Current Figure 10: 1000-hPa wind evolution around eddy-contour connection
#
# Separates the time-series figure and adds panel-specific legends for s, n, and b.
#
# - Script: `revision_20260823/artifacts/main_cyclone_wind_evolution/scripts/reorganize_eddy_cyclone_figures.py`
# - Supporting data: `revision_20260823/artifacts/main_cyclone_wind_evolution/tables/Figure8_eddy_wind_speed_series_standard.csv`
#
# ![1000-hPa wind evolution around eddy-contour connection](revision_20260823/artifacts/main_cyclone_wind_evolution/figures/Figure10_eddy_cyclone_wind_evolution_timeseries.png)

# %%
table_path = ROOT / 'publication_notebooks' / 'revision_20260823/artifacts/main_cyclone_wind_evolution/tables/Figure8_eddy_wind_speed_series_standard.csv'
pd.read_csv(table_path).head(10)
# Out:
#            case  relative_hour  wind_speed_m_s    b  n  s
# 0  BCwave_b15n1            -27       44.235561  1.5  1  0
# 1  BCwave_b15n1            -26       45.044438  1.5  1  0
# 2  BCwave_b15n1            -25       45.070476  1.5  1  0
# 3  BCwave_b15n1            -24       45.085964  1.5  1  0
# 4  BCwave_b15n1            -23       45.395618  1.5  1  0
# 5  BCwave_b15n1            -22       45.688007  1.5  1  0
# 6  BCwave_b15n1            -21       45.775912  1.5  1  0
# 7  BCwave_b15n1            -20       45.958159  1.5  1  0
# 8  BCwave_b15n1            -19       46.121659  1.5  1  0
# 9  BCwave_b15n1            -18       46.292474  1.5  1  0

# %% [markdown]
# ## Current Figure 11: Persistent-anticyclone evolution diagnosed from eddy SLP
#
# Uses eddy-SLP contours, improved spacing, corrected sectors, and two high-center labels in the local panels.
#
# - Script: `revision_20260823/artifacts/main_persistent_anticyclone/scripts/plot_figure11_eddy_qc.py`
# - Supporting data: `revision_20260823/artifacts/main_persistent_anticyclone/tables/Figure11_eddy_panel_metadata.csv`
#
# ![Persistent-anticyclone evolution diagnosed from eddy SLP](revision_20260823/artifacts/main_persistent_anticyclone/figures/Figure11_eddy_persistent_anticyclone.png)

# %%
table_path = ROOT / 'publication_notebooks' / 'revision_20260823/artifacts/main_persistent_anticyclone/tables/Figure11_eddy_panel_metadata.csv'
pd.read_csv(table_path).head(10)
# Out:
#   panel  day                         field  high_center_count  \
# 0     a    7                 500-hPa omega                  1
# 1     b    8                 500-hPa omega                  2
# 2     c    9                 500-hPa omega                  2
# 3     d   10                 500-hPa omega                  2
# 4     e   11                 500-hPa omega                  2
# 5     f   12                 500-hPa omega                  2
# 6     g   10  1000-hPa temperature anomaly                  2
# 7     h   12  1000-hPa temperature anomaly                  2
# 8     i   14  1000-hPa temperature anomaly                  2
#
#          box_bounds
# 0               NaN
# 1               NaN
# 2               NaN
# 3  100-250E, 35-65N
# 4               NaN
# 5  100-250E, 35-65N
# 6  100-250E, 35-65N
# 7  100-250E, 35-65N
# 8  100-250E, 35-65N

# %% [markdown]
# ## Current Figure 12: High-pressure eddy-SLP Hovmöller diagrams
#
# Uses 2-hPa intervals, a ±2-hPa white center, ±10-hPa limits, and corrected b-axis labels.
#
# - Script: `revision_20260823/artifacts/main_high_pressure_hovmoller/scripts/replot_figure12_eddy_hovmoller_2hpa_pm10_blabels.py`
#
# ![High-pressure eddy-SLP Hovmöller diagrams](revision_20260823/artifacts/main_high_pressure_hovmoller/figures/Figure12_eddy_high_pressure_hovmoller_2hpa_pm10_blabels.png)

# %% [markdown]
# ## Heatmap presentation revision: Eddy-SLP cyclone counts and anticyclone duration
#
# Applies the final JAMES-style panel labels, removes oversized suptitles, and retains the eddy-field diagnostics.
#
# - Script: `revision_20260823/artifacts/main_heatmaps_james_qc/scripts/replot_heatmaps_james_qc.py`
#
# ![Eddy-SLP cyclone counts and anticyclone duration](revision_20260823/artifacts/main_heatmaps_james_qc/figures/Figure6_eddy_slp_coalescence_heatmaps.png)
#
# ![Eddy-SLP cyclone counts and anticyclone duration](revision_20260823/artifacts/main_heatmaps_james_qc/figures/Figure13_eddy_anticyclone_overlap_duration.png)

# %% [markdown]
# ## SI Figures S9–S10: Initial and growth-phase upper/lower baroclinicity profiles
#
# Uses 1000–850 hPa for the lower-layer shading and labels the ensembles constant u0 and constant Umax = 30 m s−1.
#
# - Script: `revision_20260823/artifacts/si_s9_s10_upper_lower/scripts/make_upper_lower_baroclinicity_figures.py`
# - Supporting data: `revision_20260823/artifacts/si_s9_s10_upper_lower/tables/initial_vertical_profiles.nc`
# - Supporting data: `revision_20260823/artifacts/si_s9_s10_upper_lower/tables/growth_stage_flux_profiles.nc`
# - Supporting data: `revision_20260823/artifacts/si_s9_s10_upper_lower/tables/upper_lower_baroclinicity_profile_statistics.csv`
#
# ![Initial and growth-phase upper/lower baroclinicity profiles](revision_20260823/artifacts/si_s9_s10_upper_lower/figures/initial_vertical_structure_standard_vs_u30_1000_850.png)
#
# ![Initial and growth-phase upper/lower baroclinicity profiles](revision_20260823/artifacts/si_s9_s10_upper_lower/figures/eddy_flux_vertical_structure_standard_vs_u30_1000_850.png)

# %%
table_path = ROOT / 'publication_notebooks' / 'revision_20260823/artifacts/si_s9_s10_upper_lower/tables/upper_lower_baroclinicity_profile_statistics.csv'
pd.read_csv(table_path).head(10)
# Out:
#                                        figure  ensemble    b  \
# 0  initial_vertical_structure_standard_vs_u30  standard  1.0
# 1  initial_vertical_structure_standard_vs_u30  standard  1.0
# 2  initial_vertical_structure_standard_vs_u30  standard  1.0
# 3  initial_vertical_structure_standard_vs_u30  standard  1.0
# 4  initial_vertical_structure_standard_vs_u30  standard  1.0
# 5  initial_vertical_structure_standard_vs_u30  standard  1.0
# 6  initial_vertical_structure_standard_vs_u30  standard  1.0
# 7  initial_vertical_structure_standard_vs_u30  standard  1.0
# 8  initial_vertical_structure_standard_vs_u30  standard  1.0
# 9  initial_vertical_structure_standard_vs_u30  standard  1.0
#
#                         metric  pressure_hpa      mean  bootstrap_ci_low  \
# 0  initial_vertical_wind_shear          10.0  0.036216          0.033501
# 1  initial_vertical_wind_shear          50.0 -0.045168         -0.048556
# ...

# %% [markdown]
# ## SI Figure S11: RWB orientation fractions in the two ensembles
#
# Updates visible terminology to constant u0 and constant Umax = 30 m s−1.
#
# - Script: `revision_20260823/artifacts/si_s11_rwb_two_ensembles/scripts/make_original_style_comparison_figures.py`
# - Supporting data: `revision_20260823/artifacts/si_s11_rwb_two_ensembles/tables/controlled_rwb_direct_counts_all45.csv`
#
# ![RWB orientation fractions in the two ensembles](revision_20260823/artifacts/si_s11_rwb_two_ensembles/figures/Figure5_original_vs_controlled_same_style.png)

# %%
table_path = ROOT / 'publication_notebooks' / 'revision_20260823/artifacts/si_s11_rwb_two_ensembles/tables/controlled_rwb_direct_counts_all45.csv'
pd.read_csv(table_path).head(10)
# Out:
#                     case    b  n   s  cyclonic  anticyclonic  total
# 0  BCwave_b1_u30_n1_s-10  1.0  1 -10      1290           391   1681
# 1   BCwave_b1_u30_n1_s-5  1.0  1  -5      1561           690   2251
# 2    BCwave_b1_u30_n1_s0  1.0  1   0       451           939   1390
# 3    BCwave_b1_u30_n1_s5  1.0  1   5       244           714    958
# 4   BCwave_b1_u30_n1_s10  1.0  1  10       111           715    826
# 5  BCwave_b1_u30_n3_s-10  1.0  3 -10      1591            28   1619
# 6   BCwave_b1_u30_n3_s-5  1.0  3  -5      1296           194   1490
# 7    BCwave_b1_u30_n3_s0  1.0  3   0       343           331    674
# 8    BCwave_b1_u30_n3_s5  1.0  3   5       204           375    579
# 9   BCwave_b1_u30_n3_s10  1.0  3  10       153           672    825

# %% [markdown]
# ## SI Figures S12–S13: Initial cross sections with corrected colorbars
#
# Repositions colorbars without changing the underlying initial-state or conversion diagnostics.
#
# - Script: `revision_20260823/artifacts/si_s12_s13_colorbars/scripts/fix_figure_s12_colorbars.py`
# - Script: `revision_20260823/artifacts/si_s12_s13_colorbars/scripts/fix_figure_s13_colorbar.py`
#
# ![Initial cross sections with corrected colorbars](revision_20260823/artifacts/si_s12_s13_colorbars/figures/Figure_S12_initial_cross_sections_b_variation_colorbar_fixed.png)
#
# ![Initial cross sections with corrected colorbars](revision_20260823/artifacts/si_s12_s13_colorbars/figures/Figure_S13_initial_cross_sections_n_s_variations_colorbar_fixed.png)

# %% [markdown]
# ## SI Figure S14: Constant-u0 and constant-Umax relationship comparison
#
# Provides the two-ensemble predictor/response comparison with consistent terminology.
#
# - Script: `revision_20260823/artifacts/si_s14_two_ensemble_correlations/scripts/build_figure_s14_two_ensembles.py`
# - Supporting data: `revision_20260823/artifacts/si_s14_two_ensemble_correlations/tables/Figure_S14_two_ensemble_spearman_long.csv`
# - Supporting data: `revision_20260823/artifacts/si_s14_two_ensemble_correlations/tables/Figure_S14_constant_u0_correlation_matrix.csv`
# - Supporting data: `revision_20260823/artifacts/si_s14_two_ensemble_correlations/tables/Figure_S14_constant_Umax_30_ms_correlation_matrix.csv`
#
# ![Constant-u0 and constant-Umax relationship comparison](revision_20260823/artifacts/si_s14_two_ensemble_correlations/figures/Figure_S14_constant_u0_vs_constant_Umax.png)

# %%
table_path = ROOT / 'publication_notebooks' / 'revision_20260823/artifacts/si_s14_two_ensemble_correlations/tables/Figure_S14_two_ensemble_spearman_long.csv'
pd.read_csv(table_path).head(10)
# Out:
#       ensemble                     predictor                predictor_label  \
# 0  constant_u0      low_level_eady_max_day-1          Low-level Eady growth
# 1  constant_u0      low_level_eady_max_day-1          Low-level Eady growth
# 2  constant_u0      low_level_eady_max_day-1          Low-level Eady growth
# 3  constant_u0      low_level_eady_max_day-1          Low-level Eady growth
# 4  constant_u0              u_max_initial_ms                   Initial Umax
# 5  constant_u0              u_max_initial_ms                   Initial Umax
# 6  constant_u0              u_max_initial_ms                   Initial Umax
# 7  constant_u0              u_max_initial_ms                   Initial Umax
# 8  constant_u0  rossby_penetration_theory_km  Rossby penetration H_R = fL/N
# 9  constant_u0  rossby_penetration_theory_km  Rossby penetration H_R = fL/N
#
#                              response                         response_label  \
# ...

# %% [markdown]
# ## SI Figure S15: Standard-ensemble jet and low-level-baroclinicity adjustment
#
# Combines representative cross sections with independently verified Day-8/Day-15 statistics for all 45 standard cases.
#
# - Script: `revision_20260823/artifacts/si_s15_jet_adjustment/scripts/make_figure_S15_standard_ensemble_update.py`
# - Supporting data: `revision_20260823/artifacts/si_s15_jet_adjustment/tables/Figure_S15_plotted_values_all45.csv`
#
# ![Standard-ensemble jet and low-level-baroclinicity adjustment](revision_20260823/artifacts/si_s15_jet_adjustment/figures/Figure_S15_standard_ensemble_jet_adjustment.png)

# %%
table_path = ROOT / 'publication_notebooks' / 'revision_20260823/artifacts/si_s15_jet_adjustment/tables/Figure_S15_plotted_values_all45.csv'
pd.read_csv(table_path).head(10)
# Out:
#               case    b  n   s  initial_time_hour  initial_time_day  \
# 0  BCwave_b1n1s-10  1.0  1 -10                1.0          0.041667
# 1   BCwave_b1n1s-5  1.0  1  -5                1.0          0.041667
# 2      BCwave_b1n1  1.0  1   0                1.0          0.041667
# 3    BCwave_b1n1s5  1.0  1   5                1.0          0.041667
# 4   BCwave_b1n1s10  1.0  1  10                1.0          0.041667
# 5  BCwave_b1n3s-10  1.0  3 -10                1.0          0.041667
# 6   BCwave_b1n3s-5  1.0  3  -5                1.0          0.041667
# 7      BCwave_b1n3  1.0  3   0                1.0          0.041667
# 8    BCwave_b1n3s5  1.0  3   5                1.0          0.041667
# 9   BCwave_b1n3s10  1.0  3  10                1.0          0.041667
#
#    initial_u_max_300_ms  initial_jet_latitude_300_degN  \
# 0              9.922583                           34.5
# 1              9.923443                           39.5
# ...

# %% [markdown]
# ## SI Figure S19: Primary/secondary cyclone-interaction atlas
#
# Reformats the 44-case atlas from four to eight rows per page and separates the colorbar from the lowest row.
#
# - Script: `revision_20260823/artifacts/si_s19_primary_secondary_atlas/scripts/build_primary_secondary_atlas_8rows.py`
# - Supporting data: `revision_20260823/artifacts/si_s19_primary_secondary_atlas/tables/Figure_A1_primary_secondary_atlas_8rows_crosswalk.csv`
#
# ![Primary/secondary cyclone-interaction atlas](revision_20260823/artifacts/si_s19_primary_secondary_atlas/figures/Figure_A1_primary_secondary_8rows_page_01_of_05.png)
#
# ![Primary/secondary cyclone-interaction atlas](revision_20260823/artifacts/si_s19_primary_secondary_atlas/figures/Figure_A1_primary_secondary_8rows_page_02_of_05.png)
#
# ![Primary/secondary cyclone-interaction atlas](revision_20260823/artifacts/si_s19_primary_secondary_atlas/figures/Figure_A1_primary_secondary_8rows_page_03_of_05.png)
#
# ![Primary/secondary cyclone-interaction atlas](revision_20260823/artifacts/si_s19_primary_secondary_atlas/figures/Figure_A1_primary_secondary_8rows_page_04_of_05.png)
#
# ![Primary/secondary cyclone-interaction atlas](revision_20260823/artifacts/si_s19_primary_secondary_atlas/figures/Figure_A1_primary_secondary_8rows_page_05_of_05.png)

# %%
table_path = ROOT / 'publication_notebooks' / 'revision_20260823/artifacts/si_s19_primary_secondary_atlas/tables/Figure_A1_primary_secondary_atlas_8rows_crosswalk.csv'
pd.read_csv(table_path).head(10)
# Out:
#                case    b  n   s  mode  threshold_hpa  time_index  time_hour  \
# 0   BCwave_b1n1s-10  1.0  1 -10  full          990.0         336        337
# 1  BCwave_b15n1s-10  1.5  1 -10  full          990.0         316        317
# 2   BCwave_b2n1s-10  2.0  1 -10  full          990.0         310        311
# 3    BCwave_b1n1s-5  1.0  1  -5  full          990.0         311        312
# 4   BCwave_b15n1s-5  1.5  1  -5  full          990.0         284        285
# 5   BCwave_b15n3s-5  1.5  3  -5  full          990.0         328        329
# 6   BCwave_b15n6s-5  1.5  6  -5  full          990.0         356        357
# 7    BCwave_b2n1s-5  2.0  1  -5  full          990.0         273        274
# 8    BCwave_b2n3s-5  2.0  3  -5  full          990.0         320        321
# 9    BCwave_b2n6s-5  2.0  6  -5  full          990.0         349        350
#
#    target_id  n_source_ids  ... track_target_lat  track_target_lon  \
# ...

# %% [markdown]
# ## SI Figures S20–S21: Eddy-SLP anticyclone tracking and definition sensitivity
#
# Recomputes objects, tracks, lifetimes, mobility, and sensitivity statistics from eddy surface pressure rather than full SLP.
#
# - Script: `revision_20260823/artifacts/si_s20_s21_eddy_slp/scripts/recompute_figures_s20_s21_eddy_slp.py`
# - Supporting data: `revision_20260823/artifacts/si_s20_s21_eddy_slp/tables/S20_case_level_results.csv`
# - Supporting data: `revision_20260823/artifacts/si_s20_s21_eddy_slp/tables/S21_grouped_results.csv`
# - Supporting data: `revision_20260823/artifacts/si_s20_s21_eddy_slp/tables/S21_definition_audit.csv`
# - Supporting data: `revision_20260823/artifacts/si_s20_s21_eddy_slp/tables/S21_baseline_validation.csv`
#
# ![Eddy-SLP anticyclone tracking and definition sensitivity](revision_20260823/artifacts/si_s20_s21_eddy_slp/figures/Figure_S20_eddy_slp_lifetime_centroid_speed.png)
#
# ![Eddy-SLP anticyclone tracking and definition sensitivity](revision_20260823/artifacts/si_s20_s21_eddy_slp/figures/Figure_S21_eddy_slp_definition_sensitivity.png)

# %%
table_path = ROOT / 'publication_notebooks' / 'revision_20260823/artifacts/si_s20_s21_eddy_slp/tables/S20_case_level_results.csv'
pd.read_csv(table_path).head(10)
# Out:
#                case    b  n   s                   definition_id  \
# 0   BCwave_b1n1s-10  1.0  1 -10  S20_plus10_overlap0.3_identity
# 1   BCwave_b1n3s-10  1.0  3 -10  S20_plus10_overlap0.3_identity
# 2   BCwave_b1n6s-10  1.0  6 -10  S20_plus10_overlap0.3_identity
# 3  BCwave_b15n1s-10  1.5  1 -10  S20_plus10_overlap0.3_identity
# 4  BCwave_b15n3s-10  1.5  3 -10  S20_plus10_overlap0.3_identity
# 5  BCwave_b15n6s-10  1.5  6 -10  S20_plus10_overlap0.3_identity
# 6   BCwave_b2n1s-10  2.0  1 -10  S20_plus10_overlap0.3_identity
# 7   BCwave_b2n3s-10  2.0  3 -10  S20_plus10_overlap0.3_identity
# 8   BCwave_b2n6s-10  2.0  6 -10  S20_plus10_overlap0.3_identity
# 9    BCwave_b1n1s-5  1.0  1  -5  S20_plus10_overlap0.3_identity
#
#                                     method  eddy_threshold_hpa  \
# 0  independent_permissive_overlap_identity                  10
# 1  independent_permissive_overlap_identity                  10
# 2  independent_permissive_overlap_identity                  10
# ...

# %% [markdown]
# ## Table S3: Eddy-SLP persistence, size, intensity, and centroid mobility
#
# Recomputes the fixed n=1, s=+10° table consistently with the eddy-SLP tracker used for Figures S20–S21.
#
# - Script: `revision_20260823/artifacts/table_s3_eddy_slp/scripts/recompute_table_s3_eddy_slp.py`
# - Supporting data: `revision_20260823/artifacts/table_s3_eddy_slp/tables/Table_S3_eddy_slp_recomputed.csv`
# - Supporting data: `revision_20260823/artifacts/table_s3_eddy_slp/tables/Table_S3_old_full_field_vs_new_eddy_slp.csv`
# - Supporting data: `revision_20260823/artifacts/table_s3_eddy_slp/tables/Table_S3_validation_against_Figure_S20.csv`

# %%
table_path = ROOT / 'publication_notebooks' / 'revision_20260823/artifacts/table_s3_eddy_slp/tables/Table_S3_eddy_slp_recomputed.csv'
pd.read_csv(table_path).head(10)
# Out:
#               case    b  n   s display_case  \
# 0   BCwave_b1n1s10  1.0  1  10      b1n1s10
# 1  BCwave_b15n1s10  1.5  1  10    b1.5n1s10
# 2   BCwave_b2n1s10  2.0  1  10      b2n1s10
#
#                                          source_file  \
# 0  /data/keeling/a/mingfei5/a/data/original/BCwav...
# 1  /data/keeling/a/mingfei5/a/data/original/BCwav...
# 2  /data/keeling/a/mingfei5/a/data/original/BCwav...
#
#                                  eddy_slp_definition  eddy_threshold_hpa  \
# 0  PRESsfc minus instantaneous zonal mean at each...                10.0
# 1  PRESsfc minus instantaneous zonal mean at each...                10.0
# 2  PRESsfc minus instantaneous zonal mean at each...                10.0
#
#    minimum_area_km2  identity_overlap_threshold  ...  mean_area_1e6_km2  \
# 0          100000.0                         0.3  ...           2.193247
# 1          100000.0                         0.3  ...           5.524811
# ...

# %% [markdown]
# ## EP-flux supplementary diagnostic: EP-flux evolution during the baroclinic-wave life cycle
#
# Uses pressure-coordinate QG EP flux, corrected log-pressure presentation, less-dense lower-level vectors, and common scales.
#
# - Script: `revision_20260823/artifacts/ep_flux_evolution/scripts/compute_r1_6_ep_flux_evolution.py`
#
# ![EP-flux evolution during the baroclinic-wave life cycle](revision_20260823/artifacts/ep_flux_evolution/figures/r1_6_ep_flux_evolution.png)

# %% [markdown]
# ## Initial-PV supplementary diagnostic: Initial PV and dynamical-tropopause structure across b, n, and s
#
# Expands the original three-panel latitude-shift comparison to a controlled 3×3 b/n/s comparison with shared levels and labeled theta contours.
#
# - Script: `revision_20260823/artifacts/initial_pv_bns/scripts/compute_r1_11_initial_pv_cross_sections_bns.py`
#
# ![Initial PV and dynamical-tropopause structure across b, n, and s](revision_20260823/artifacts/initial_pv_bns/figures/r1_11_initial_pv_cross_sections_bns.png)

# %% [markdown]
# ## Section 3.2 consolidated diagnostic: Vertical profiles, Eady growth, NH EKE, and mature-stage eddy fluxes
#
# Consolidates four two-column comparisons with consistent panel numbering and constant-u0/constant-Umax terminology.
#
# - Script: `revision_20260823/artifacts/section32_combined/scripts/make_section32_figures.py`
# - Supporting data: `revision_20260823/artifacts/section32_combined/tables/initial_profiles_at_jet_core.csv`
# - Supporting data: `revision_20260823/artifacts/section32_combined/tables/eke_nh_area_mass_weighted_timeseries_all90.csv`
# - Supporting data: `revision_20260823/artifacts/section32_combined/tables/eddy_flux_profiles_50_80pct_peak_eke_all90.csv`
#
# ![Vertical profiles, Eady growth, NH EKE, and mature-stage eddy fluxes](revision_20260823/artifacts/section32_combined/figures/section32_four_part_combined_8panels.png)

# %%
table_path = ROOT / 'publication_notebooks' / 'revision_20260823/artifacts/section32_combined/tables/initial_profiles_at_jet_core.csv'
pd.read_csv(table_path).head(10)
# Out:
#    ensemble             case    b  n   s  pressure_hpa  \
# 0  standard  BCwave_b1n1s-10  1.0  1 -10          10.0
# 1  standard  BCwave_b1n1s-10  1.0  1 -10          50.0
# 2  standard  BCwave_b1n1s-10  1.0  1 -10         100.0
# 3  standard  BCwave_b1n1s-10  1.0  1 -10         150.0
# 4  standard  BCwave_b1n1s-10  1.0  1 -10         200.0
# 5  standard  BCwave_b1n1s-10  1.0  1 -10         250.0
# 6  standard  BCwave_b1n1s-10  1.0  1 -10         300.0
# 7  standard  BCwave_b1n1s-10  1.0  1 -10         400.0
# 8  standard  BCwave_b1n1s-10  1.0  1 -10         500.0
# 9  standard  BCwave_b1n1s-10  1.0  1 -10         600.0
#
#    initial_zonal_wind_at_jet_core_m_s-1  initial_eady_growth_rate_day-1  \
# 0                              0.015421                        0.004778
# 1                              0.027734                        0.005361
# 2                              0.405482                        0.041259
# ...

# %% [markdown]
# ## Reproduction and provenance
#
# The exact scripts and compact supporting tables are stored under `publication_notebooks/revision_20260823/artifacts/`. Large raw SHiELD NetCDF files are intentionally not duplicated in the Git repository. Scripts retain the original Keeling data dependencies documented in the project README and individual analysis reports. `SHA256SUMS` records every file included in this revision bundle.
